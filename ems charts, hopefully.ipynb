# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
ems = pd.read_csv('EMS_Incident_Dispatch_Data (1).csv')
low_memory=False
ems.tail(5)
# Out:
# C:\Users\jason\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 8557843        183653775  12/31/2018 09:22:44 PM             OTHER
# 8557844        183653969  12/31/2018 10:12:43 PM              SHOT
# 8557845        183654050  12/31/2018 10:33:43 PM             OTHER
# 8557846        183654167  12/31/2018 11:00:43 PM             OTHER
# 8557847        183654276  12/31/2018 11:31:55 PM            UNKNOW
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 8557843                            6           OTHER
# 8557844                            3            SHOT
# 8557845                            6           OTHER
# 8557846                            6           OTHER
# ...

# %%
ems = ems[['INCIDENT_DATETIME', 'INITIAL_CALL_TYPE', 'INITIAL_SEVERITY_LEVEL_CODE', 'FINAL_CALL_TYPE', 'BOROUGH', 'ZIPCODE']]

# %%
ems.tail()
# Out:
#               INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 8557843  12/31/2018 09:22:44 PM             OTHER
# 8557844  12/31/2018 10:12:43 PM              SHOT
# 8557845  12/31/2018 10:33:43 PM             OTHER
# 8557846  12/31/2018 11:00:43 PM             OTHER
# 8557847  12/31/2018 11:31:55 PM            UNKNOW
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 8557843                            6           OTHER
# 8557844                            3            SHOT
# 8557845                            6           OTHER
# 8557846                            6           OTHER
# 8557847                            4          UNKNOW
#
#                           BOROUGH  ZIPCODE
# 8557843                 MANHATTAN  10027.0
# 8557844                     BRONX  10466.0
# 8557845                     BRONX  10462.0
# 8557846                  BROOKLYN  11207.0
# 8557847  RICHMOND / STATEN ISLAND  10310.0

# %%
ems.head()
# Out:
#         INCIDENT_DATETIME INITIAL_CALL_TYPE  INITIAL_SEVERITY_LEVEL_CODE  \
# 0  01/01/2013 12:00:04 AM            RESPIR                            4
# 1  01/01/2013 12:00:19 AM              CARD                            3
# 2  01/01/2013 12:01:04 AM            ARREST                            1
# 3  01/01/2013 12:01:16 AM              SICK                            6
# 4  01/01/2013 12:01:26 AM            INJURY                            5
#
#   FINAL_CALL_TYPE BOROUGH  ZIPCODE
# 0          RESPIR   BRONX  10472.0
# 1            CARD   BRONX  10454.0
# 2          ARREST  QUEENS  11418.0
# 3            SICK   BRONX  10453.0
# 4          INJURY   BRONX  10457.0

# %%
from datetime import datetime

# %%
ems['INCIDENT_DATE'] = ems['INCIDENT_DATETIME']

# %%
type(ems['INCIDENT_DATETIME'])
# Out:
# pandas.core.series.Series

# %%
ems['INCIDENT_DATE'] = ems['INCIDENT_DATETIME'].str.split(' ').str[0]

# %%
ems.head()
# Out:
#         INCIDENT_DATETIME INITIAL_CALL_TYPE  INITIAL_SEVERITY_LEVEL_CODE  \
# 0  01/01/2013 12:00:04 AM            RESPIR                            4
# 1  01/01/2013 12:00:19 AM              CARD                            3
# 2  01/01/2013 12:01:04 AM            ARREST                            1
# 3  01/01/2013 12:01:16 AM              SICK                            6
# 4  01/01/2013 12:01:26 AM            INJURY                            5
#
#   FINAL_CALL_TYPE BOROUGH  ZIPCODE INCIDENT_DATE
# 0          RESPIR   BRONX  10472.0    01/01/2013
# 1            CARD   BRONX  10454.0    01/01/2013
# 2          ARREST  QUEENS  11418.0    01/01/2013
# 3            SICK   BRONX  10453.0    01/01/2013
# 4          INJURY   BRONX  10457.0    01/01/2013

# %%
date_format = "%Y-%m-%dT%H:%M:%S.%f"
s= datetime.strptime(results[0]['incident_datetime'], date_format)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2c24b9027f60> in <module>
#       1 date_format = "%Y-%m-%dT%H:%M:%S.%f"
# ----> 2 s= datetime.strptime(results[0]['incident_datetime'], date_format)
#
# NameError: name 'results' is not defined

# %%
pd.to_datetime(ems['INCIDENT_DATE'])
# Out:
# 0         2013-01-01
# 1         2013-01-01
# 2         2013-01-01
# 3         2013-01-01
# 4         2013-01-01
# 5         2013-01-01
# 6         2013-01-01
# 7         2013-01-01
# 8         2013-01-01
# 9         2013-01-01
# 10        2013-01-01
# 11        2013-01-01
# 12        2013-01-01
# 13        2013-01-01
# 14        2013-01-01
# 15        2013-01-01
# 16        2013-01-01
# 17        2013-01-01
# 18        2013-01-01
# 19        2013-01-01
# 20        2013-01-01
# 21        2013-01-01
# 22        2013-01-01
# 23        2013-01-01
# 24        2013-01-01
# 25        2013-01-01
# 26        2013-01-01
# 27        2013-01-01
# 28        2013-01-01
# 29        2013-01-01
#              ...
# 8557818   2018-12-30
# 8557819   2018-12-30
# 8557820   2018-12-30
# 8557821   2018-12-30
# 8557822   2018-12-30
# 8557823   2018-12-30
# 8557824   2018-12-31
# 8557825   2018-12-31
# 8557826   2018-12-31
# 8557827   2018-12-31
# 8557828   2018-12-31
# 8557829   2018-12-31
# ...

# %%
ems.head()
# Out:
#         INCIDENT_DATETIME INITIAL_CALL_TYPE  INITIAL_SEVERITY_LEVEL_CODE  \
# 0  01/01/2013 12:00:04 AM            RESPIR                            4
# 1  01/01/2013 12:00:19 AM              CARD                            3
# 2  01/01/2013 12:01:04 AM            ARREST                            1
# 3  01/01/2013 12:01:16 AM              SICK                            6
# 4  01/01/2013 12:01:26 AM            INJURY                            5
#
#   FINAL_CALL_TYPE BOROUGH  ZIPCODE INCIDENT_DATE
# 0          RESPIR   BRONX  10472.0    01/01/2013
# 1            CARD   BRONX  10454.0    01/01/2013
# 2          ARREST  QUEENS  11418.0    01/01/2013
# 3            SICK   BRONX  10453.0    01/01/2013
# 4          INJURY   BRONX  10457.0    01/01/2013
